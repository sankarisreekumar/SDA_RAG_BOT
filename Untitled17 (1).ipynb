# %%
# !pip install chromadb sentence-transformers transformers accelerate bitsandbytes

# %%
import os
import chromadb
from sentence_transformers import SentenceTransformer
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# %%
file_paths = [
    "/content/DSA.txt",
    "/content/faculty.txt",
    "/content/fee and infra.txt",
    "/content/syallbus.txt",
    "/content/elective course.txt"
]

# %%
embed_model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
chroma_client = chromadb.PersistentClient(path="./text_vectorstore")
collection = chroma_client.get_or_create_collection(name="sda_collection")

# %%
all_chunks = []

for file_path in file_paths:
    try:
        with open(file_path, "r", encoding="utf-8") as f:
            text = f.read()

        chunk_id = os.path.basename(file_path).replace(" ", "_")
        all_chunks.append((chunk_id, text))
        print(f"✔ Loaded {file_path}")
    except Exception as e:
        print(f"❌ Error loading {file_path}: {e}")
# Out:
# ✔ Loaded /content/DSA.txt
# ✔ Loaded /content/faculty.txt
# ✔ Loaded /content/fee and infra.txt
# ✔ Loaded /content/syallbus.txt
# ✔ Loaded /content/elective course.txt

# %%
for chunk_id, text in all_chunks:
    emb = embed_model.encode([text]).tolist()
    collection.add(
        documents=[text],
        embeddings=emb,
        ids=[chunk_id]
    )

print("\n All text files are now embedded in ChromaDB!")
# Out:
#  All text files are now embedded in ChromaDB!

# %%
# Example: Qwen2.5-Instruct (FREE, no login)
MODEL_NAME = "Qwen/Qwen2.5-1.5B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    device_map="auto",
    torch_dtype=torch.float16
)

# %%
def generate_answer(query):
    # 1️⃣ Embed the query
    q_emb = embed_model.encode([query]).tolist()

    # 2️⃣ Retrieve top chunks from Chroma
    results = collection.query(
        query_embeddings=q_emb,
        n_results=4
    )

    retrieved_text = "\n\n".join(results["documents"][0])

    # 3️⃣ Prompt for LLM
    prompt = f"""
You are an expert advisor for the School of Data Analytics (SDA).
Use ONLY the context below to answer the user's question.
If the answer is not found in the context, say 'No data found.'

### CONTEXT:
{retrieved_text}

### QUESTION:
{query}

### ANSWER:
"""

    # 4️⃣ Tokenize and generate
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    output = model.generate(
        **inputs,
        max_new_tokens=300,
        temperature=0.2
    )

    answer = tokenizer.decode(output[0], skip_special_tokens=True)
    return answer.split("### ANSWER:")[-1].strip()

# %%
questions = [
    "Tell me about the course syllabus.",
    "Which electives are available?",
    "Explain the evaluation scheme.",
    "How is the course structured?",
    "How long is the project?",
    "What is the contact number of SDA?",
    "Tell me about the faculty members",
    "What is the fee structure and infrastructure?"
]

for q in questions:
    answer = generate_answer(q)
    print(f"\n❓ Question: {q}")
    print(f"💡 Answer: {answer}")
# Out:
# ❓ Question: Tell me about the course syllabus.
# 💡 Answer: The course syllabus outlines the structure of the M.Sc. Data Science and Analytics program, detailing the credit distribution across different semesters. Here’s a summary of the key points:
#
# **Semester I:**
# - **Core Courses:** Introduction to Data Science & Data Analytics (3 credits), Linear Algebra and Matrices (3 credits), Probability and Distribution Theory (3 credits), Database Management Systems (3 credits), Programming in Python for Data Science (3 credits), Statistical Inference (3 credits), Practical: Data Science Lab (3 credits).
#
# **Semester II:**
# - **Core Courses:** Sampling Methods & Design of Experiments (3 credits), Applied Multivariate Analysis (3 credits), Applied Regression Analysis (3 credits), Programming in R for Data Analytics (3 credits), Data Visualization and Presentation (3 credits), Elective 1 (3 credits), Elective 2 (3 credits), Practical: Data Analytics Lab (3 credits).
#
# **Semester III:**
# - **Core Courses:** Machine Learning (3 credits), Stochastic Modeling & Time Series Forecasting (3 credits), Artificial Intelligence (3 credits), Elective 3 (4 credits), Elective 4 (4 credits), Practical: Computer Lab (3 credits), Open Course (4 credits).
#
# **Semester IV:**
# - **Core Courses:** Elective 5 (3 credits), Project/Dissertation (9 credits), Project Presentation & Viva Voce (4 credits).
#
# Each semester totals 21, 2
#
# ❓ Question: Which electives are available?
# 💡 Answer: E1 – Neural Networks and Deep Learning – 3 credits
# E2 – Bayesian Inference & Computing – 3 credits
# E3 – Big Data and Hadoop – 4 credits
# E4 – Information Retrieval Techniques – 3 credits
# E5 – Data Warehousing & Data Mining – 3 credits
# E6 – Web Scraping and Text Mining – 3 credits
# E7 – Natural Language Processing with Python – 4 credits
# E8 – Fraud Analytics – 3 credits
# E9 – Internet of Things in the Cloud – 3 credits
# E10 – Operations Research – 4 credits
# E11 – Cloud Computing – 3 credits
# E12 – Business Intelligence & Analytics – 4 credits
# E13 – Data Analytics Computing – 3 credits
# E14 – Complex Network Analysis – 4 credits
#
# ❓ Question: Explain the evaluation scheme.
# 💡 Answer: The evaluation scheme for the M.Sc. Data Science & Analytics program includes a combination of coursework assessments and practical assignments. The grading scale typically ranges from A+ to F, where A+ indicates excellent performance, while F represents failure. Additionally, there may be exams or projects that contribute to the final grade, depending on the specific course requirements. For instance, in SEMESTER I, students take courses like "Introduction to Data Science & Data Analytics" and "Linear Algebra and Matrices," which could involve both written tests and practical exercises. Similarly, in SEMESTER II, students engage in more advanced topics such as "Sampling Methods & Design of Experiments" and "Applied Multivariate Analysis," which might include presentations and case studies. Throughout the semester, regular quizzes, group discussions, and individual assignments also play crucial roles in assessing student understanding and application skills. It's important to consult the official syllabus and guidelines provided by the school for detailed information about the exact evaluation methods used in each course. No data found.
#
# ❓ Question: How is the course structured?
# 💡 Answer: The course structure includes 19 core courses totaling 64 credits, 5 elective courses totaling 17 credits, and 1 open course of 4 credits, resulting in a grand total of 85 credits. The program aims to provide advanced knowledge in Data Science and Analytics, equip students with practical skills in statistical methods and computer programming, and prepare them for roles in data-driven industries. Additionally, the program offers opportunities for internships and collaborative research with industry partners.
#
# ❓ Question: How long is the project?
# 💡 Answer: The project for M.Sc. Data Science & Analytics lasts for 9 credits.
#
# ❓ Question: What is the contact number of SDA?
# 💡 Answer: +91-9446560608, 8304870247
#
# ❓ Question: Tell me about the faculty members
# 💡 Answer: Dr. K K Jose, Dr. Ancy Joseph, Dr. Sharon Susan Jacob, Mr. Jiby Joseph, Ms. Abseena Habeeb, Ms. Ragi G. R, Dr. Satheesh S, Dr. Ajitha Sasi, Mrs. Beteena Kurian. They hold qualifications such as M.Sc., M.Phil., Ph.D., FRSS, FSMS, PhD, MTech, and teach in the School of Data Analytics. Their roles include being directors, coordinators, heads of departments, visiting faculties, and co-ordinators. They are located at different addresses and email domains. The infrastructure includes a computer lab with 28 computers and a smart classroom equipped with projector, smart TV, audio system, and digital learning tools. Fees for the program are ₹28000 for the first semester, ₹29000 for the second, third, and fourth semesters. The duration of the program is four semesters, lasting two years. The program aims to prepare students for careers in data science and analytics, offering a mix of core and elective courses, and encouraging interdisciplinary studies. The faculty encourages students to explore emerging areas of data science and analytics, including Bayesian inference, stochastic modeling, time series forecasting, and fraud analytics. The program structure includes core courses, elective courses, and an open elective course, totaling 85 credits over four semesters. The eligibility criteria require a bachelor’s degree
#
# ❓ Question: What is the fee structure and infrastructure?
# 💡 Answer: The fee structure for the M.Sc. Data Science & Analytics program includes different rates for each semester. For example, the fee for Semester 1 is ₹28000, while the fee for Semester 2 is ₹29000. Additionally, there is a fixed fee of ₹28000 for Semesters 3 and 4. Regarding infrastructure, the institution provides facilities such as a computer lab with 28 computers, high-speed internet access, and updated software tools. Furthermore, there is a smart classroom equipped with a projector, smart TV, audio system, and digital learning tools.
